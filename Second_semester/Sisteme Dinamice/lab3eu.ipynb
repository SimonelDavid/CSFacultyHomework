# %%
#lab3
reset()
C1, C2 = var('C1,C2')
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x, t) == x + 4*y
eq2 = diff(y, t) == x + y
sis = [eq1, eq2]
sol = desolve_system(sis, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
eq1 = diff(x, t) == 2*x - y
eq2 = diff(y, t) == x + 2*y
sis = [eq1, eq2]
sol = desolve_system(sis, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]

# %%
z = function('z')(t)
C3 = var('C3')
eq1 = diff(x, t) == x - y + z
eq2 = diff(y, t) == x + y -z

eq3 = diff(z, t) == -y + 2*z
sis = [eq1, eq2, eq3]
sol = desolve_system(sis, [x, y, z], [0, C1, C2, C3])
show(sol)
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %%
eq1 = diff(x, t) == 5 * x  + 3 * y +1
eq2 = diff(y, t) == (-6) * x - 4*y + e^(-t)
sis = [eq1, eq2]
sol = desolve_system(sis, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
eq1 = diff(x, t) ==x + 3*y + cos(t)
eq2 = diff(y, t) == x - y + 2*t
sis = [eq1, eq2]
sol = desolve_system(sis, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
z = function('z')(t)
C3 = var('C3')
eq1 = diff(x, t) == x - 2*y - 2*z + e^(-t)
eq2 = diff(y, t) == (-2) * x + y + 2*z

eq3 = diff(z, t) == 2*x - y -3*z + e^(-t)
sis = [eq1, eq2, eq3]
sol = desolve_system(sis, [x, y, z], [0, C1, C2, C3])
show(sol)
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]

# %%
#exercițiul 2

# %%
eq1 = diff(x, t) == x + 4*y
eq2 = diff(y, t) == x + y
sis = [eq1, eq2]
sol = desolve_system(sis, [x, y], [0, 1, 2])
show(sol)
plot(sol[0].rhs(), -1, 1)
plot(sol[1].rhs(), -1, 1)
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]
# Graphics object consisting of 1 graphics primitive

# %%
eq1 = diff(x, t) == x - y + t - 1
eq2 = diff(y, t) == (-2)*x + 4 * y + cos(t)
sis = [eq1, eq2]
sol = desolve_system(sis, [x, y], [0, 0, 1])
show(sol)
show(plot(sol[0].rhs(), -1, 1) + plot(sol[1].rhs(), -1, 1))
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]
# Graphics object consisting of 2 graphics primitives

# %%
eq1 = diff(x, t) == x + 2*y + e ^(-t)
eq2 = diff(y, t) == (-2)*x + y + 1
sis = [eq1, eq2]
sol = desolve_system(sis, [x, y], [0, 0, 1])
show(sol)
show(plot(sol[0].rhs(), -1, 1) + plot(sol[1].rhs(), -1, 1))
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]
# Graphics object consisting of 2 graphics primitives

# %%
eq1 = diff(x, t) == -x + 3*y + 3*z + 27*(t^2)
eq2 = diff(y, t) == 2*x - 2*y - 5*z + 3*t

eq3 = diff(z, t) == -2*x + 3*y + 6*z + 3
sis = [eq1, eq2, eq3]
sol = desolve_system(sis, [x, y, z], [0,50, -30, 26])
show(sol)
show(plot(sol[0].rhs(), -1, 1) 
     + plot(sol[1].rhs(), -1, 1)
    + plot(sol[2].rhs(), -1, 1))
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]
# Graphics object consisting of 3 graphics primitives

# %%
#exercitiul 3

# %%
eq1 = diff(x, t) == x + y
eq2 = diff(y, t) == (-2)*x + 4*y
sis = [eq1, eq2]
sol1 = desolve_system(sis, [x, y], [0, 3, 0])
show(sol1)
sol2 = desolve_system(sis, [x, y], [0, 0, 3])
show(sol2)
sol3 = desolve_system(sis, [x, y], [0, -3, 0])
show(sol3)
sol4 = desolve_system(sis, [x, y], [0, 0, -3])
show(sol4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd4bc44c33c5> in <module>()
# ----> 1 eq1 = diff(x, t) == x + y
#       2 eq2 = diff(y, t) == (-Integer(2))*x + Integer(4)*y
#       3 sis = [eq1, eq2]
#       4 sol1 = desolve_system(sis, [x, y], [Integer(0), Integer(3), Integer(0)])
#       5 show(sol1)
#
# NameError: name 't' is not defined

# %%
solutii = [sol1, sol2, sol3, sol4]
for solutie in solutii:
    show(limit(solutie[0].rhs(), t = infinity))
    show(limit(solutie[1].rhs(), t = infinity))
# Out:
# -Infinity
# -Infinity
# +Infinity
# +Infinity
# +Infinity
# +Infinity
# -Infinity
# -Infinity

# %%
f1(u, v) = u + v
f2(u, v) = -2 *u + 4*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)

g=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-5,5], [v,-5,5],color='red' ,aspect_ratio = 1)
for sol in solutii:
    sol_x(t) = sol[0].rhs()
    sol_y(t) = sol[1].rhs() 
    g += parametric_plot((sol_x(t), sol_y(t)), (t, -10, 10),color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
#exercițiul 4

# %%
eq1 = diff(x, t) == y(t)
eq2 = diff(y, t) == -x(t) - 2*y(t)
syst = [eq1, eq2]
sol = desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t),
#  y(t) == -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)]

# %%
show(lim(sol[0].rhs(), t = infinity))
show(lim(sol[1].rhs(), t = infinity))
# Out:
# 0
# 0

# %%
f1(u, v) = v
f2(u, v) = -u - 2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -5, 5], [v, -5, 5], color='green', aspect_ratio = 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#exercițiul 5

# %%
f1(u, v) = 2*u + v
f2(u, v) = u + 2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u, v)/n, f2(u, v)/n],
                  [u, -5, 5],
                  [v, -5, 5],
                  color='green',
                  aspect_ratio = 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = -u - v
f2(u, v) = u - v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
plot_vector_field([f1(u, v)/n, f2(u, v)/n],
                 [u, -5, 5],
                 [v, -5, 5],
                 color='blue',
                 aspect_ratio =1)
#aici este lim = lim = 0
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = v
f2(u, v) = -u
n = sqrt(f1(u, v)^2+f2(u, v)^2)
plot_vector_field([f1(u, v)/n, f2(u, v)/n],
                 [u, -5, 5], 
                 [v, -5, 5],
                 color= 'red',
                 aspect_ratio = 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = -2*u
f2(u, v) = -4*u - 2*v
n = sqrt(f1(u, v)^2+f2(u, v)^2)
plot_vector_field([f1(u, v)/n, f2(u, v)/n],
                 [u, -5, 5], 
                 [v, -5, 5],
                 color= 'red',
                 aspect_ratio = 1)
# aici lim = lim = 0
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = u - 4*v
f2(u, v) = 5*u - 3*v
n = sqrt(f1(u, v)^2+f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n],
                 [u, -5, 5], 
                 [v, -5, 5],
                 color= 'red',
                 aspect_ratio = 1)
deq1=diff(x,t)==x - 4*y
deq2=diff(y,t)==5*x - 3*y
sol = desolve_system([deq1, deq2], [x, y], [0, 1, 1])
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs() 
g += parametric_plot((sol_x(t), sol_y(t)),
                     (t, -10, 10),
                     color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# lim = lim = 0
# Out:
# [x(t) == 1/2*(2*cos(4*t) - sin(4*t))*e^(-t),
#  y(t) == 1/4*(4*cos(4*t) + 3*sin(4*t))*e^(-t)]
# Graphics object consisting of 2 graphics primitives

# %%
f1(u, v) = 3*u - v
f2(u, v) = v
n = sqrt(f1(u, v)^2+f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n],
                 [u, -5, 5], 
                 [v, -5, 5],
                 color= 'red',
                 aspect_ratio = 1)
deq1=diff(x,t)==3*x - y
deq2=diff(y,t)==y
for i in [-3..2]:
    for j in [-3..2]:
        
        sol = desolve_system([deq1, deq2], [x, y], [0, i, j])
        #show(sol)
        sol_x(t) = sol[0].rhs()
        sol_y(t) = sol[1].rhs() 
        g += parametric_plot((sol_x(t), sol_y(t)),
                         (t, -10, 10),
                         color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# lim = lim = 0
# Out:
# Graphics object consisting of 37 graphics primitives
